# %%
# import modules
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read in data
df = pd.read_csv('prem_league_data_processed.csv')

# %%
# saved CSV with an exra column, dropping it
df.drop(columns = 'Unnamed: 0', inplace = True)
df
# Out:
#        season  wk        date  day ha             team         opponent  gf  \
# 0        1993   1  1992-08-15  Sat  H    Coventry City    Middlesbrough   2
# 1        1993   1  1992-08-15  Sat  A    Middlesbrough    Coventry City   1
# 2        1993   1  1992-08-15  Sat  A        Wimbledon     Leeds United   1
# 3        1993   1  1992-08-15  Sat  H     Leeds United        Wimbledon   2
# 4        1993   1  1992-08-15  Sat  H    Sheffield Utd   Manchester Utd   2
# ...       ...  ..         ...  ... ..              ...              ...  ..
# 24047    2023  38  2023-05-28  Sun  H      Aston Villa         Brighton   2
# 24048    2023  38  2023-05-28  Sun  A        Tottenham     Leeds United   4
# 24049    2023  38  2023-05-28  Sun  H     Leeds United        Tottenham   1
# 24050    2023  38  2023-05-28  Sun  H        Brentford  Manchester City   1
# 24051    2023  38  2023-05-28  Sun  A  Manchester City        Brentford   0
#
#        ga ftr
# 0       1   W
# 1       2   L
# ...

# %%
df.describe()
# Out:
#             season            wk            gf            ga
# count  24052.00000  24052.000000  24052.000000  24052.000000
# mean    2007.71362     19.730501      1.333444      1.333444
# std        9.07237     11.123684      1.238003      1.238003
# min     1993.00000      1.000000      0.000000      0.000000
# 25%     2000.00000     10.000000      0.000000      0.000000
# 50%     2008.00000     20.000000      1.000000      1.000000
# 75%     2016.00000     29.000000      2.000000      2.000000
# max     2023.00000     42.000000      9.000000      9.000000

# %%
df.day.value_counts(normalize = True)
# Out:
# day
# Sat    0.572260
# Sun    0.195160
# Wed    0.091302
# Mon    0.066938
# Tue    0.051056
# Fri    0.012057
# Thu    0.011226
# Name: proportion, dtype: float64

# %%
df.team.value_counts()
# Out:
# team
# Everton            1190
# Liverpool          1190
# Chelsea            1190
# Manchester Utd     1190
# Arsenal            1190
# Tottenham          1190
# Aston Villa        1076
# Newcastle Utd      1072
# West Ham           1034
# Manchester City    1000
# Southampton         924
# Blackburn           696
# Leicester City      650
# Sunderland          608
# Fulham              608
# Leeds United        582
# Middlesbrough       574
# Crystal Palace      540
# Bolton              494
# West Brom           494
# Norwich City        392
# Stoke City          380
# Coventry City       354
# Wolves              342
# Wimbledon           316
# Sheffield Weds      316
# Burnley             304
# Wigan Athletic      304
# Charlton Ath        304
# Watford             304
# QPR                 278
# Birmingham City     266
# Portsmouth          266
# Swansea City        266
# Derby County        266
# Nott'ham Forest     236
# Brighton            228
# Bournemouth         228
# ...

# %% [markdown]
# ## Visualize Categorical Variables

# %%
sns.catplot(data=df, x='season', kind='count', aspect=4)

plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df, x='day', kind='count')

plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df, y='team', kind='count', height=20)

plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df, x='ftr', kind='count')

plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df, x='gf', kind='count')

plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df, x='ga', kind='count')

plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# **Findings**
# * Seasons were shortened after 1995
# * The vast majority of games were played on Saturday
# * Teams like Manchester United, Arsenal, Everton, Tottenham, Chelsea, and Liverpool have not been relegated between 1993-2023, and therefore have the most games
# * Most games end with a winner
# * Most games see at least zero or one goal scored with multiple goals scored for one team having a steep drop off after 2 goals scored

# %% [markdown]
# ### Explore relationships between catgeorical variables
#
# I'll look at the overall dataset and key-in on one team - Arsenal

# %%
sns.catplot(data=df, x='season', hue='ftr', aspect=4, kind='count')
plt.title('Full-Time Results per Season')

plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df.loc[df.team == 'Arsenal'], x='season', hue='ftr', aspect=4, kind='count')
plt.title('Arsenal - Full-Time Results per Season')

plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df, x='day', hue='ftr', aspect=2, kind='count')
plt.title('Full-Time Results per Day')

plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df.loc[df.team == 'Arsenal'], x='day', hue='ftr', aspect=2, kind='count')
plt.title('Arsenal - Full-Time Results per Day')

plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df, x='gf', hue='ftr', aspect=2, kind='count')
plt.title('Full-Time Results per Goals For')

plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df.loc[df.team == 'Arsenal'], x='gf', hue='ftr', aspect=2, kind='count')
plt.title('Arsenal - Full-Time Results per Goals For')

plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df, x='ga', hue='ftr', aspect=2, kind='count')
plt.title('Full-Time Results per Goals Against')

plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df.loc[df.team == 'Arsenal'], x='ga', hue='ftr', aspect=2, kind='count')
plt.title('Arsenal - Full-Time Results per Goals Against')

plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df, y='opponent', hue='ftr', height=20, kind='count')
plt.title('Full-Time Results per Opponent')

plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df.loc[df.team == 'Arsenal'], y='opponent', hue='ftr', height=20, kind='count')
plt.title('Arsenal - Full-Time Results per Opponent')

plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# **Findings**
# * Visually, it looks like as time progressed, draws across the league were less common
# * With the exception of 1993-1995 and 2020, Arsenal have had significantly winning records
# * Draws seem to have more of a share of results across the league on Wednesdays
# * Arsenal seem to lose more often on Thursdays, but dominate on all other days of the week
# * For both Arsenal and the rest of the league, if a team scores 2 goals, they are very likely to win, the inverse is true as well
# * Manchester United seem to be the toughest opponent from 1993-2023, handing losses to most of their opponents, while teams like Sunderland and West Ham do just the opposite
# * For Arsenal, teams like Liverpool, Manchester United, and Brighton best them in an overall series, but Arsenal do outperform all other teams, with the exception of rival Tottenham, who they draw even with very often

# %% [markdown]
# ### Grouping by team

# %%
# group by team and aggregate summary stats
df_team = df.groupby('team').agg(
    games_played=('ftr', 'count'),
    wins=('ftr', lambda x: (x == 'W').sum()),
    draws=('ftr', lambda x: (x == 'D').sum()),
    losses=('ftr', lambda x: (x == 'L').sum()),
    gf=('gf', 'sum'),
    ga=('ga', 'sum'),
).reset_index()

# add a goal differential column
df_team['gd'] = df_team.gf - df_team.ga

# add stats per game
df_team['win%'] = df_team.wins / df_team.games_played
df_team['draw%'] = df_team.draws / df_team.games_played
df_team['loss%'] = df_team.losses / df_team.games_played
df_team['avg_gf'] = df_team.gf / df_team.games_played
df_team['avg_ga'] = df_team.ga / df_team.games_played
df_team['avg_gd'] = df_team.gd / df_team.games_played

df_team
# Out:
#                team  games_played  wins  draws  losses    gf    ga    gd  \
# 0           Arsenal          1190   645    290     255  2105  1191   914
# 1       Aston Villa          1076   372    303     401  1316  1399   -83
# 2          Barnsley            38    10      5      23    37    82   -45
# 3   Birmingham City           266    73     82     111   273   360   -87
# 4         Blackburn           696   262    184     250   927   907    20
# 5         Blackpool            38    10      9      19    55    78   -23
# 6            Bolton           494   149    128     217   575   745  -170
# 7       Bournemouth           228    67     49     112   278   401  -123
# 8     Bradford City            76    14     20      42    68   138   -70
# 9         Brentford            76    28     21      27   106   102     4
# 10         Brighton           228    66     73      89   262   311   -49
# 11          Burnley           304    83     76     145   300   455  -155
# ...

# %%
sns.displot(data=df_team, x='games_played', kind='hist', kde=True, bins=10)
plt.title('Distribution of Games Played')
plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=df_team, x='wins', kind='hist', kde=True, bins=10)
plt.title('Distribution of Total Wins')
plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=df_team, x='win%', kind='hist', kde=True, bins=10)
plt.title('Distribution of Win Percentages')
plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=df_team, x='draws', kind='hist', kde=True, bins=10)
plt.title('Distribution of Total Draws')
plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=df_team, x='draw%', kind='hist', kde=True, bins=10)
plt.title('Distribution of Draw Percentages')
plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=df_team, x='losses', kind='hist', kde=True, bins=10)
plt.title('Distribution of Total Losses')
plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=df_team, x='loss%', kind='hist', kde=True, bins=10)
plt.title('Distribution of Loss Percentages')
plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=df_team, x='gf', kind='hist', kde=True, bins=10)
plt.title('Distribution of Total Goals For')
plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=df_team, x='avg_gf', kind='hist', kde=True, bins=10)
plt.title('Distribution of Goals For per Game')
plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=df_team, x='ga', kind='hist', kde=True, bins=10)
plt.title('Distribution of Total Goals Against')
plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=df_team, x='avg_ga', kind='hist', kde=True, bins=10)
plt.title('Distribution of Goals Against per Game')
plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=df_team, x='gd', kind='hist', kde=True, bins=10)
plt.title('Distribution of Overall Goal Differentials')
plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=df_team, x='avg_gd', kind='hist', kde=True, bins=10)
plt.title('Distribution of Goals Differentials per Game')
plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# **Findings**
# * Most teams have fewer than 300 total games played in the league, but we see a handful of teams who have over 1000 games played
# * Most teams have won less than 150 total games and win percentages have the highest concentration just under 30%
# * There are far less draws than wins recorded, but the total number of draws are distributed more evenly with the highest concentation of draws being around 25% of games
# * Losses are extremely high with most teams holding around a 45% loss record
# * With the above points in mind, it makes sense that the average goal differential sits around -0.25 across the league

# %% [markdown]
# ### Bivarate Analysis

# %%
sns.catplot(data=df, x='ftr', y='gf', kind='violin', hue='ftr')
plt.title('Avg Goals For vs. Full-Time Result')
plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df, x='ftr', y='ga', kind='violin', hue='ftr')
plt.title('Avg Goals Against vs. Full-Time Result')
plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# To visualize home and away and `ftr`, I'll change the variables to be:
# * `0` for home
# * `1` for away

# %%
df['ha'] = df['ha'].replace({'H':0, 'A':1})
df.head()
# Out:
#    season  wk        date  day  ha           team        opponent  gf  ga ftr
# 0    1993   1  1992-08-15  Sat   0  Coventry City   Middlesbrough   2   1   W
# 1    1993   1  1992-08-15  Sat   1  Middlesbrough   Coventry City   1   2   L
# 2    1993   1  1992-08-15  Sat   1      Wimbledon    Leeds United   1   2   L
# 3    1993   1  1992-08-15  Sat   0   Leeds United       Wimbledon   2   1   W
# 4    1993   1  1992-08-15  Sat   0  Sheffield Utd  Manchester Utd   2   1   W

# %%
sns.catplot(data=df, x='ftr', y='ha', kind='violin', hue='ftr')
plt.title('Home or Away vs. Full-Time Result')
plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.catplot(data=df, x='ftr', y='ha', kind='violin', hue='day', aspect=3)

plt.show()
# Out:
# /opt/anaconda3/envs/cmpinf2100/lib/python3.8/site-packages/seaborn/axisgrid.py:123: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %% [markdown]
# **Findings**
# * Wins are more concentrated at Home games, while Losses are more concentrated at Away games. Draws see an even share and this does not seem to change across different days

# %%
# save dataframe with updated `ha` column
df.to_csv('prem_league_data_for_modeling.csv')
